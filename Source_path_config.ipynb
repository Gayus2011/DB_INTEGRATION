# %%
#Config Source files
landing_path = '/Volumes/test-json-file-catalog/landing_schema/test_json_files/customer_personal_100_records_invalid.json'
bronze_schema_path = '`test-json-file-catalog`.bronze_schema'
silver_schema_path = '`test-json-file-catalog`.silver_schema'
gold_schema_path = '`test-json-file-catalog`.gold_schema'
# Schema location and checkpoint location paths for Auto Loader

# schema_location = '/Volumes/test-json-file-catalog/landing_schema/test_json_files/_schemas'
# checkpoint_location = '/Volumes/test-json-file-catalog/landing_schema/test_json_files/_checkpoints/bronze_customer'

#CSV files source path, schema, checkpoint, targettable location
csv_source_path = "/Volumes/test-json-file-catalog/landing_schema/test_csv_files/"
bronze_csv_table_path = "`test-json-file-catalog`.bronze_schema.cust_prof_info_csv_tablenew"
bronze_json_table_path = "`test-json-file-catalog`.bronze_schema.cust_prof_info_tablenew"
schema_location = "/Volumes/test-json-file-catalog/landing_schema/test_csv_files/_schema/cust_prof_info_csv_tablenew"
checkpoint_location = "/Volumes/test-json-file-catalog/landing_schema/test_csv_files/_checkpoint/cust_prof_info_csv_tablenew"

#Target table paths
bronze_csv_target_table = "`test-json-file-catalog`.bronze_schema.cust_prof_info_csv_tablenew"
silver_csv_target_table = "`test-json-file-catalog`.silver_schema.cust_prof_info_csv_tablenew"
gold_csv_target_table = "`test-json-file-catalog`.gold_schema.cust_prof_info_csv_tablenew"

#Json files source path, schema, checkpoint, targettable location
source_path_json = "/Volumes/test-json-file-catalog/landing_schema/test_json_files/"
schema_location_json = "/Volumes/test-json-file-catalog/landing_schema/test_json_files/_schema/cust_prof_info_tablenew"
checkpoint_location_json = "/Volumes/test-json-file-catalog/landing_schema/test_json_files/_checkpoint/cust_prof_info_tablenew"

#Target table paths
bronze_json_target_table = "`test-json-file-catalog`.bronze_schema.cust_prof_info_tablenew"
silver_json_target_table = "`test-json-file-catalog`.silver_schema.cust_prof_info_tablenew"
gold_json_target_table = "`test-json-file-catalog`.gold_schema.cust_prof_info_tablenew"
